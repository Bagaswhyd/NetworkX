# %% [markdown]
# # Layout Algorithm using NetworkX Assignment

# %% [markdown]
# Nama: Muhammad Bagas Wahyudi
#
# NIM: 1301220296
#
# Kelas: ANALISIS JEJARING SOSIAL IF-46-DSIS.01 [YLS]

# %% [markdown]
# # Install Scrapy

# %%
pip install scrapy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.9/352.9 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 60.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.8/269.8 kB 22.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 6.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Programming Data Capture

# %%
import scrapy

class QuotesSpider(scrapy.Spider):
    name = "quotes"
    start_urls = [
        "https://quotes.toscrape.com/tag/humor/",
    ]

    def parse(self, response):
        for quote in response.css("div.quote"):
            yield {
                "author": quote.xpath("span/small/text()").get(),
                "text": quote.css("span.text::text").get(),
            }

        next_page = response.css('li.next a::attr("href")').get()
        if next_page is not None:
            yield response.follow(next_page, self.parse)

# %% [markdown]
# # Layout Algorithm

# %% [markdown]
# ## 1. Bipartite graph

# %%
import networkx as nx
import matplotlib.pyplot as plt
K33 = nx.complete_bipartite_graph(3, 3)
nx.draw(K33)
plt.show()

# %% [markdown]
# ## 2. Spring Layout

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.dodecahedral_graph()
# default layout = spring
nx.draw(G)
plt.show()

# %% [markdown]
# ## 3. Shell Layout

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.dodecahedral_graph()
nx.draw(G, pos=nx.shell_layout(G))
plt.show()

# %% [markdown]
# ## 4. Spiral Layout

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.dodecahedral_graph()
# default layout = spring
nx.draw(G, pos=nx.spiral_layout(G))
plt.show()
